# %%
import tensorflow
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense, LSTM, GRU

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=10000)

x_train = pad_sequences(x_train, maxlen=100)
x_test = pad_sequences(x_test, maxlen=100)

# %%
# Simple RNN model
model = Sequential([
    Embedding(10000, 32, input_length=100),
    SimpleRNN(5, return_sequences=True),
    SimpleRNN(5),
    Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 32)           320000
#
#  simple_rnn (SimpleRNN)      (None, 100, 5)            190
#
#  simple_rnn_1 (SimpleRNN)    (None, 5)                 55
#
#  dense (Dense)               (None, 1)                 6
#
# =================================================================
# Total params: 320,251
# Trainable params: 320,251
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=5, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/5
# 625/625 [==============================] - 11s 17ms/step - loss: 0.6787 - accuracy: 0.5539 - val_loss: 0.5655 - val_accuracy: 0.7300
# Epoch 2/5
# 625/625 [==============================] - 10s 16ms/step - loss: 0.4079 - accuracy: 0.8250 - val_loss: 0.4837 - val_accuracy: 0.7842
# Epoch 3/5
# 625/625 [==============================] - 10s 16ms/step - loss: 0.2401 - accuracy: 0.9088 - val_loss: 0.5066 - val_accuracy: 0.7832
# Epoch 4/5
# 625/625 [==============================] - 10s 16ms/step - loss: 0.1413 - accuracy: 0.9528 - val_loss: 0.5806 - val_accuracy: 0.7856
# Epoch 5/5
# 625/625 [==============================] - 10s 16ms/step - loss: 0.0952 - accuracy: 0.9699 - val_loss: 0.6443 - val_accuracy: 0.7870

# %%
# LSTM model
model = Sequential([
    Embedding(10000, 32, input_length=100),
    LSTM(5, return_sequences=True),
    LSTM(5),
    Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 100, 32)           320000
#
#  lstm_1 (LSTM)               (None, 100, 5)            760
#
#  lstm_2 (LSTM)               (None, 5)                 220
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 320,986
# Trainable params: 320,986
# Non-trainable params: 0
# _________________________________________________________________

# %%
# GRU model
model = Sequential([
    Embedding(10000, 32, input_length=100),
    GRU(5, return_sequences=True),
    GRU(5),
    Dense(1, activation='sigmoid')
])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_3 (Embedding)     (None, 100, 32)           320000
#
#  gru (GRU)                   (None, 100, 5)            585
#
#  gru_1 (GRU)                 (None, 5)                 180
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 320,771
# Trainable params: 320,771
# Non-trainable params: 0
# _________________________________________________________________
